# %% [markdown]
# | Employee_ID | Experience (Years) |                          Salary (₹) |
# | ----------- | -----------------: | ----------------------------------: |
# | 101         |                  1 |                               30000 |
# | 102         |                  2 |                               35000 |
# | 103         |                  3 |                               40000 |
# | 104         |                  4 |                                 nan |
# | 105         |                  5 |                               50000 |
# | 106         |                nan |                               55000 |
# | 107         |                  7 |                               60000 |
# | 108         |                  8 |                               65000 |
# | 109         |                  9 |                               70000 |
# | 110         |                 10 |                               75000 |
# | 111         |                  2 |                               36000 |
# | 112         |                  3 |                                 nan |
# | 113         |                nan |                               52000 |
# | 114         |                  5 |                               51000 |
# | 115         |                  6 |                               56000 |
# | 116         |                  8 |                              180000 |
# | 117         |                  9 |                               15000 |
# | 118         |                 10 |                               76000 |
# | 119         |                  4 |                               45000 |
# | 120         |                  4 |                               45000 |

# %% [markdown]
# 1. Load the dataset.
#
# 2. Display the first and last five records.
#
# 3. Check the shape of the dataset.
#
# 4. Display the data types of each column.
#
# 5. Find missing values.
#
# 6. Count the missing values in each column.
#
# 7. Fill the missing values using:
# * Mean
# * Median
#
# 8. Detect duplicate records.
#
# 9. Remove duplicate records.
#
# 10. Plot:
# * Scatter plot (Experience vs Salary)
# * Histogram of Salary
# * Box plot of Salary
#
# 11. Identify the outliers.
#
# 12. Remove the outliers using the IQR method.
#
# 13. Compare the scatter plot before and after removing outliers.
#
# 14. Build a Linear Regression model from scratch (manual calculation of m and b, without using scikit-learn).
#
# 15. Calculate the prediction error (MSE).
#
# 16. Predict the salary for:
# * 7.5 years of experience
# * 11 years of experience
#
# 17. Compare the model's performance:
# * Before data cleaning
# * After data cleaning
